# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/8-thsem -internship/cleaned_superstore_dataset.csv")

# %%
df.describe()
# Out:
#               sales      quantity      discount        profit  shipping_cost  \
# count  48660.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     161.017838      3.476545      0.142908     28.641740      26.375915
# std      201.092519      2.278766      0.212280    174.424113      57.296804
# min        0.000000      1.000000      0.000000  -6599.978000       0.000000
# 25%       29.000000      2.000000      0.000000      0.000000       2.610000
# 50%       77.000000      3.000000      0.000000      9.240000       7.790000
# 75%      208.000000      5.000000      0.200000     36.810000      24.450000
# max      999.000000     14.000000      0.850000   8399.976000     933.570000
#
#                year  delivery_days  profit_margin
# count  51290.000000   51290.000000   48659.000000
# mean    2012.777208       3.969370       0.041939
# std        1.098931       1.729437       0.474660
# min     2011.000000       0.000000      -4.727752
# 25%     2012.000000       3.000000       0.000000
# 50%     2013.000000       4.000000       0.168453
# 75%     2014.000000       5.000000       0.334459
# max     2014.000000       7.000000       0.582800

# %%
category_sales = df.groupby("category")["sales"].sum()

plt.figure()
category_sales.plot(kind="bar")
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
profit_category = df.groupby("category")["profit"].sum()

plt.figure()
profit_category.plot(kind="bar")
plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Total Profit")
plt.show()

# %%
region_sales = df.groupby("region")["sales"].sum()

plt.figure()
region_sales.plot(kind="bar")
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()

# %%
corr = df[["sales","profit","discount","quantity"]].corr()

plt.figure()
plt.imshow(corr)
plt.title("Correlation Matrix")
plt.colorbar()
plt.show()

# %%
top_products = df.groupby("product_name")["sales"].sum().sort_values(ascending=False).head(10)

plt.figure()
top_products.plot(kind="bar")
plt.title("Top 10 Products by Sales")
plt.show()

# %%
df["order_date"] = pd.to_datetime(df["order_date"])

monthly_sales = df.groupby(df["order_date"].dt.month)["sales"].sum()

plt.figure()
monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()
